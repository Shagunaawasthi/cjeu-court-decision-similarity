# %%
import pandas as pd
import os

df = pd.read_csv(os.path.join(os.path.join(os.path.realpath('..'), "outputdata"), "results.csv"))

print(len(df))
# Out:
# 219480

# %%
df.drop_duplicates(subset=None, keep='first', inplace=False)
overlapsDf = df[df["citation_link"] == True]
print(overlapsDf.head(100))
print(len(overlapsDf))
# Out:
#       source_case     similar_case  similarity_score method  citation_link  \
# 0     62003CJ0453      62006CO0421          0.727373  tfidf           True
# 20    61988CJ0070      61987CJ0302          0.689978  tfidf           True
# 21    61988CJ0070  61988CJ0070(01)          0.515609  tfidf           True
# 40    61980CJ0272      61996CJ0400          0.592285  tfidf           True
# 42    61980CJ0272      61994CJ0293          0.506306  tfidf           True
# 47    61980CJ0272      61988CJ0025          0.448330  tfidf           True
# 48    61980CJ0272      62003CJ0432          0.422753  tfidf           True
# 60    62009CJ0229      62012CJ0210          0.901442  tfidf           True
# 61    62009CJ0229      62013CJ0011          0.788711  tfidf           True
# 63    62009CJ0229      61998CJ0306          0.609271  tfidf           True
# 80    62003CJ0211      62005CJ0319          0.648130  tfidf           True
# 83    62003CJ0211      62007CJ0140          0.574549  tfidf           True
# 86    62003CJ0211      61988CJ0369          0.553020  tfidf           True
# 100   61987CJ0187      62003CJ0061          0.438568  tfidf           True
# 102   61987CJ0187      62008CJ0115          0.372678  tfidf           True
# 109   61987CJ0187      61999CJ0029          0.324585  tfidf           True
# 120   62007CJ0270      61997CJ0374          0.694262  tfidf           True
# 121   62007CJ0270      62007CJ0309          0.656554  tfidf           True
# 122   62007CJ0270      62000CJ0284          0.607634  tfidf           True
# 127   62007CJ0270      62009CJ0523          0.465783  tfidf           True
# 130   62007CJ0270      62015CJ0112          0.418635  tfidf           True
# 140   62005CJ0174      62005CJ0138          0.570309  tfidf           True
# 163   62016CJ0078      62002CJ0140          0.297986  tfidf           True
# 189   61973CJ0039      61982CJ0314          0.310888  tfidf           True
# 204   62005CJ0326      62016CJ0244          0.298738  tfidf           True
# 215   62005CJ0326      62009CJ0077          0.191955  tfidf           True
# 217   62005CJ0326      62008CO0517          0.183496  tfidf           True
# 220   62013CJ0528      62009CJ0421          0.774991  tfidf           True
# 241   62006CO0459      61998CO0364          0.436529  tfidf           True
# 244   62006CO0459      61998CO0043          0.408020  tfidf           True
# ...           ...              ...               ...    ...            ...
# 1288  62007CJ0378      62007CO0364          0.803285  tfidf           True
# 1289  62007CJ0378      62009CJ0109          0.796181  tfidf           True
# 1292  62007CJ0378      62013CJ0190          0.774242  tfidf           True
# 1293  62007CJ0378      62006CJ0268          0.766239  tfidf           True
# 1295  62007CJ0378      62010CO0272          0.760454  tfidf           True
# 1297  62007CJ0378      62010CO0003          0.752573  tfidf           True
# 1298  62007CJ0378      62004CJ0144          0.742397  tfidf           True
# 1300  61995CJ0261      61995CJ0094          0.648213  tfidf           True
# 1302  61995CJ0261      61995CJ0373          0.552661  tfidf           True
# 1304  61995CJ0261      62006CJ0445          0.535641  tfidf           True
# 1317  61995CJ0261      61996CJ0228          0.290939  tfidf           True
# 1320  62009CJ0447      62007CJ0388          0.605003  tfidf           True
# 1321  62009CJ0447      62009CJ0045          0.572014  tfidf           True
# 1324  62009CJ0447      62007CJ0555          0.532460  tfidf           True
# 1326  62009CJ0447      62013CJ0416          0.486645  tfidf           True
# 1327  62009CJ0447      62008CJ0088          0.485185  tfidf           True
# 1333  62009CJ0447      62008CJ0229          0.457364  tfidf           True
# 1334  62009CJ0447      62012CJ0286          0.442389  tfidf           True
# 1339  62009CJ0447      62016CJ0143          0.420767  tfidf           True
# 1340  61993CJ0007      62000CJ0351          0.650412  tfidf           True
# 1341  61993CJ0007      61991CJ0110          0.600455  tfidf           True
# 1350  61993CJ0007      61999CJ0366          0.549630  tfidf           True
# 1353  61993CJ0007      62002CJ0004          0.536553  tfidf           True
# 1368  61996CJ0416      61991CJ0237          0.408009  tfidf           True
# 1372  61996CJ0416      61996CJ0036          0.396507  tfidf           True
# 1374  61996CJ0416      61996CJ0098          0.388304  tfidf           True
# 1375  61996CJ0416      62005CJ0097          0.387735  tfidf           True
# 1382  61993CJ0449      62005CJ0187          0.575259  tfidf           True
# 1385  61993CJ0449      62005CJ0270          0.561363  tfidf           True
# 1388  61993CJ0449      62008CJ0044          0.549796  tfidf           True
#
#      source_case_topic
# 0        public health
# 20       public health
# 21       public health
# 40       public health
# 42       public health
# 47       public health
# 48       public health
# 60       public health
# 61       public health
# 63       public health
# 80       public health
# 83       public health
# 86       public health
# 100      public health
# 102      public health
# 109      public health
# 120      public health
# 121      public health
# 122      public health
# 127      public health
# 130      public health
# 140      public health
# 163      public health
# 189      public health
# 204      public health
# 215      public health
# 217      public health
# 220      public health
# 241      public health
# 244      public health
# ...                ...
# 1288     social policy
# 1289     social policy
# 1292     social policy
# 1293     social policy
# 1295     social policy
# 1297     social policy
# 1298     social policy
# 1300     social policy
# 1302     social policy
# 1304     social policy
# 1317     social policy
# 1320     social policy
# 1321     social policy
# 1324     social policy
# 1326     social policy
# 1327     social policy
# 1333     social policy
# 1334     social policy
# 1339     social policy
# 1340     social policy
# 1341     social policy
# 1350     social policy
# 1353     social policy
# 1368     social policy
# 1372     social policy
# 1374     social policy
# 1375     social policy
# 1382     social policy
# 1385     social policy
# 1388     social policy
#
# [100 rows x 6 columns]
# 8553
